# %% [markdown]
# <a href="https://colab.research.google.com/github/somesyd/Colab/blob/main/small_med_genre_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# authenticate with your Google account
from google.colab import auth
auth.authenticate_user()

# %%
meta_small = 'meta_small.csv'
meta_medium = 'meta_medium.csv'

# %%
# link to the Google Cloud Platform project with the storage bucket
project_id = 'audio-philes-test'
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %%
# copy the 'file_name' file from the fma_metadata folder
#   audio_philes_data is the Google Storage bucket name
#   saving to a tmp directory
# !gsutil cp gs://audio_philes_data/modified/{meta_small} /tmp/{meta_small}
# !gsutil cp gs://audio_philes_data/modified/{meta_medium} /tmp/{meta_medium}

# print the first line of the file to check the transfer was successful
# !head -n 5 /tmp/{meta_small}
# Out:
# Copying gs://audio_philes_data/modified/meta_small.csv...
# / [1 files][397.0 KiB/397.0 KiB]
# Operation completed over 1 objects/397.0 KiB.
# Copying gs://audio_philes_data/modified/meta_medium.csv...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# track_id,bit_rate,genre_top,genres,genres_all,top_genre_id,parent
# 2,256000.0,Hip-Hop,[21],[21],21,0
# 5,256000.0,Hip-Hop,[21],[21],21,0
# 10,192000.0,Pop,[10],[10],10,0
# 140,128000.0,Folk,[17],[17],17,0

# %%
import numpy as np
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
df = pd.read_csv("/tmp/" + meta_small)

df
# Out:
#       track_id  bit_rate genre_top          genres      genres_all  \
# 0            2  256000.0   Hip-Hop            [21]            [21]
# 1            5  256000.0   Hip-Hop            [21]            [21]
# 2           10  192000.0       Pop            [10]            [10]
# 3          140  128000.0      Folk            [17]            [17]
# 4          141  128000.0      Folk            [17]            [17]
# ...        ...       ...       ...             ...             ...
# 7995    154308  320000.0   Hip-Hop  [21, 539, 811]  [811, 539, 21]
# 7996    154309  320000.0   Hip-Hop  [21, 539, 811]  [811, 539, 21]
# 7997    154413  320000.0       Pop            [76]        [10, 76]
# 7998    154414  320000.0       Pop            [76]        [10, 76]
# 7999    155066  320000.0   Hip-Hop       [21, 811]       [811, 21]
#
#       top_genre_id  parent
# 0               21       0
# 1               21       0
# 2               10       0
# 3               17       0
# ...

# %%
df2 = pd.read_csv("/tmp/" + meta_medium)

df2
# Out:
# ...
#        track_id  bit_rate     genre_top           genres       genres_all  \
# 0             2  256000.0       Hip-Hop             [21]             [21]
# 1             3  256000.0       Hip-Hop             [21]             [21]
# 2             5  256000.0       Hip-Hop             [21]             [21]
# 3            10  192000.0           Pop             [10]             [10]
# 4           134  256000.0       Hip-Hop             [21]             [21]
# ...         ...       ...           ...              ...              ...
# 24995    155297  320000.0  Instrumental  [18, 107, 1235]  [107, 18, 1235]
# 24996    155298  320000.0          Folk        [17, 103]        [17, 103]
# 24997    155306  320000.0          Folk        [17, 103]        [17, 103]
# 24998    155307  320000.0  Experimental              [1]          [1, 38]
# 24999    155314  320000.0          Rock             [25]         [25, 12]
#
#        top_genre_id  parent
# 0                21       0
# ...

# %%
df_null = df2[df2.isna().any(axis=1)]
df_null
# Out:
# Empty DataFrame
# Columns: [track_id, bit_rate, genre_top, genres, genres_all, top_genre_id, parent]
# Index: []
